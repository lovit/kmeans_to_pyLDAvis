# %%
# add path

import sys
sys.path.append('../')
import kmeans_visualizer
import soyclustering
# Out:
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Load data

import pickle

with open('../data/2016-10-20-news-bow.pkl', 'rb') as f:
    params = pickle.load(f)
    x = params['x']
    index2word = params['index2word']

# %%
# kmeans

from soyclustering import SphericalKMeans
from sklearn.feature_extraction.text import TfidfTransformer

x_tfidf = TfidfTransformer().fit_transform(x)
kmeans = SphericalKMeans(n_clusters=300, verbose=1)
labels = kmeans.fit_predict(x_tfidf)
centers = kmeans.cluster_centers_
# Out:
# initialization_time=0.519668 sec, sparsity=0.00739
# n_iter=1, changed=29960, inertia=18760.640, iter_time=2.988 sec, sparsity=0.167
# n_iter=2, changed=5804, inertia=14321.722, iter_time=2.631 sec, sparsity=0.15
# n_iter=3, changed=2291, inertia=13754.888, iter_time=2.635 sec, sparsity=0.145
# n_iter=4, changed=1213, inertia=13555.802, iter_time=2.624 sec, sparsity=0.143
# n_iter=5, changed=770, inertia=13444.430, iter_time=2.628 sec, sparsity=0.141
# n_iter=6, changed=554, inertia=13375.289, iter_time=2.622 sec, sparsity=0.141
# n_iter=7, changed=357, inertia=13333.484, iter_time=2.629 sec, sparsity=0.14
# n_iter=8, changed=220, inertia=13313.098, iter_time=2.625 sec, sparsity=0.14
# n_iter=9, changed=159, inertia=13302.514, iter_time=2.635 sec, sparsity=0.14
# n_iter=10, changed=132, inertia=13292.480, iter_time=2.623 sec, sparsity=0.14

# %%
# visualize
from kmeans_visualizer import kmeans_to_prepared_data

prepared_data = kmeans_to_prepared_data(x, index2word, centers, labels, n_printed_words=40, radius=2)

# %%
import pyLDAvis

# pyLDAvis.save_html(prepared_data, 'kmeans_pyLDAvis.html')
pyLDAvis.display(prepared_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el273721399249611698401634069153"></div>
# <script type="text/javascript">
#
# ...
